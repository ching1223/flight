# %% [markdown]
# # Histogram

# %%
import pandas as pd
from datetime import datetime
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# 載入資料並刪除價格歷史為空的列
data = pd.read_csv('/Users/yuchingchen/Documents/專題/cleaned_data/short_flight_final.csv')

# 移除包含 NaN 的數據
plot_data = data.dropna(subset=["平均價格_log", "最低價格_log", "最低價格天數", "價格變異_log", "中位數價格_log", "隨機購買平均價格"])

min_value = plot_data['最低價格'].min()
print("最低價格的最小值為：", min_value)

# 用布林索引過濾出「最低價格」等於最小值的所有列
rows_with_min_value = plot_data[plot_data['最低價格'] == min_value]

print(rows_with_min_value)
print("最低價格的最小值的數量為：", len(rows_with_min_value))
# Out:
# 最低價格的最小值為： 1340
#             出發日期   星期    出發時間  出發時段 出發機場代號     抵達時間  抵達時段 抵達機場代號  機場分類  \
# 1723  2025-01-20  星期一  下午2:05  下午班機    TPE   下午4:05  下午抵達    HKG   2.0
# 1724  2025-01-20  星期一  下午2:50  下午班機    TPE   下午4:55  下午抵達    HKG   2.0
# 1790  2025-01-21  星期二  下午2:05  下午班機    TPE   下午4:05  下午抵達    HKG   2.0
# 1791  2025-01-21  星期二  下午2:50  下午班機    TPE   下午4:55  下午抵達    HKG   2.0
# 1792  2025-01-21  星期二  下午5:40  下午班機    TPE   晚上7:35  晚間抵達    HKG   2.0
# 1825  2025-01-21  星期二  晚上9:10  晚間班機    TPE  晚上11:10  晚間抵達    HKG   2.0
# 1857  2025-01-22  星期三  下午2:10  下午班機    TPE   下午4:05  下午抵達    HKG   2.0
# 1858  2025-01-22  星期三  下午2:50  下午班機    TPE   下午4:55  下午抵達    HKG   2.0
# 1859  2025-01-22  星期三  下午5:40  下午班機    TPE   晚上7:35  晚間抵達    HKG   2.0
# 1890  2025-01-22  星期三  晚上9:10  晚間班機    TPE  晚上11:10  晚間抵達    HKG   2.0
# 1921  2025-01-23  星期四  下午2:10  下午班機    TPE   下午4:05  下午抵達    HKG   2.0
# 1922  2025-01-23  星期四  下午2:50  下午班機    TPE   下午4:55  下午抵達    HKG   2.0
# 1923  2025-01-23  星期四  下午5:40  下午班機    TPE   晚上7:35  晚間抵達    HKG   2.0
# 1956  2025-01-23  星期四  晚上9:10  晚間班機    TPE  晚上11:10  晚間抵達    HKG   2.0
# 2600  2025-02-06  星期四  下午2:10  下午班機    TPE   下午4:05  下午抵達    HKG   2.0
# 2601  2025-02-06  星期四  下午2:50  下午班機    TPE   下午4:55  下午抵達    HKG   2.0
# 2621  2025-02-06  星期四  晚上9:10  晚間班機    TPE  晚上11:10  晚間抵達    HKG   2.0
# 2664  2025-02-07  星期五  晚上9:10  晚間班機    TPE  晚上11:10  晚間抵達    HKG   2.0
# 2771  2025-02-10  星期一  下午2:05  下午班機    TPE   下午4:05  下午抵達    HKG   2.0
# 2772  2025-02-10  星期一  下午2:50  下午班機    TPE   下午4:55  下午抵達    HKG   2.0
# 2825  2025-02-11  星期二  下午2:05  下午班機    TPE   下午4:05  下午抵達    HKG   2.0
# 2826  2025-02-11  星期二  下午2:50  下午班機    TPE   下午4:55  下午抵達    HKG   2.0
# 2827  2025-02-11  星期二  下午5:40  下午班機    TPE   晚上7:35  晚間抵達    HKG   2.0
# 2860  2025-02-11  星期二  晚上9:10  晚間班機    TPE  晚上11:10  晚間抵達    HKG   2.0
# 2883  2025-02-12  星期三  下午2:10  下午班機    TPE   下午4:05  下午抵達    HKG   2.0
# 2884  2025-02-12  星期三  下午2:50  下午班機    TPE   下午4:55  下午抵達    HKG   2.0
# 2885  2025-02-12  星期三  下午5:40  下午班機    TPE   晚上7:35  晚間抵達    HKG   2.0
# 2905  2025-02-12  星期三  晚上9:10  晚間班機    TPE  晚上11:10  晚間抵達    HKG   2.0
# 2926  2025-02-13  星期四  下午2:10  下午班機    TPE   下午4:05  下午抵達    HKG   2.0
# 2927  2025-02-13  星期四  下午2:50  下午班機    TPE   下午4:55  下午抵達    HKG   2.0
# 2928  2025-02-13  星期四  下午5:40  下午班機    TPE   晚上7:35  晚間抵達    HKG   2.0
# 2948  2025-02-13  星期四  晚上9:10  晚間班機    TPE  晚上11:10  晚間抵達    HKG   2.0
# 2969  2025-02-14  星期五  下午2:10  下午班機    TPE   下午4:05  下午抵達    HKG   2.0
# 2970  2025-02-14  星期五  下午2:50  下午班機    TPE   下午4:55  下午抵達    HKG   2.0
# 2971  2025-02-14  星期五  下午5:40  下午班機    TPE   晚上7:35  晚間抵達    HKG   2.0
# 2991  2025-02-14  星期五  晚上9:10  晚間班機    TPE  晚上11:10  晚間抵達    HKG   2.0
# 3034  2025-02-15  星期六  晚上9:10  晚間班機    TPE  晚上11:10  晚間抵達    HKG   2.0
# 3105  2025-02-17  星期一  下午2:05  下午班機    TPE   下午4:05  下午抵達    HKG   2.0
# 3106  2025-02-17  星期一  下午2:50  下午班機    TPE   下午4:55  下午抵達    HKG   2.0
# 3152  2025-02-18  星期二  下午2:05  下午班機    TPE   下午4:05  下午抵達    HKG   2.0
# 3153  2025-02-18  星期二  下午2:50  下午班機    TPE   下午4:55  下午抵達    HKG   2.0
# 3154  2025-02-18  星期二  下午5:40  下午班機    TPE   晚上7:35  晚間抵達    HKG   2.0
# 3178  2025-02-18  星期二  晚上9:10  晚間班機    TPE  晚上11:10  晚間抵達    HKG   2.0
# 3202  2025-02-19  星期三  下午2:10  下午班機    TPE   下午4:05  下午抵達    HKG   2.0
# 3203  2025-02-19  星期三  下午2:50  下午班機    TPE   下午4:55  下午抵達    HKG   2.0
# 3204  2025-02-19  星期三  下午5:40  下午班機    TPE   晚上7:35  晚間抵達    HKG   2.0
# 3224  2025-02-19  星期三  晚上9:10  晚間班機    TPE  晚上11:10  晚間抵達    HKG   2.0
# 3247  2025-02-20  星期四  下午2:10  下午班機    TPE   下午4:05  下午抵達    HKG   2.0
# 3248  2025-02-20  星期四  下午2:50  下午班機    TPE   下午4:55  下午抵達    HKG   2.0
# 3249  2025-02-20  星期四  下午5:40  下午班機    TPE   晚上7:35  晚間抵達    HKG   2.0
# 3269  2025-02-20  星期四  晚上9:10  晚間班機    TPE  晚上11:10  晚間抵達    HKG   2.0
#
#         航空公司  ...  最低價格_log 價格變異_log 中位數價格_log 最低價格天數  Region  \
# 1723  香港快運航空  ...       7.2    12.84      7.43     30      香港
# 1724  香港快運航空  ...       7.2    12.84      7.43     30      香港
# 1790  香港快運航空  ...       7.2    13.10      7.43     29      香港
# 1791  香港快運航空  ...       7.2    13.22      7.32     29      香港
# 1792  香港快運航空  ...       7.2    12.75      7.50     29      香港
# 1825  香港快運航空  ...       7.2    12.98      7.33     29      香港
# 1857  香港快運航空  ...       7.2    12.78      7.50     28      香港
# 1858  香港快運航空  ...       7.2    12.79      7.37     28      香港
# 1859  香港快運航空  ...       7.2    12.69      7.50     28      香港
# 1890  香港快運航空  ...       7.2    12.67      7.32     28      香港
# 1921  香港快運航空  ...       7.2    13.74      7.54     27      香港
# 1922  香港快運航空  ...       7.2    13.47      7.54     27      香港
# 1923  香港快運航空  ...       7.2    13.60      7.50     27      香港
# 1956  香港快運航空  ...       7.2    12.84      7.43     27      香港
# 2600  香港快運航空  ...       7.2    12.69      7.65     13      香港
# 2601  香港快運航空  ...       7.2    12.68      7.65     13      香港
# 2621  香港快運航空  ...       7.2    12.69      7.50     13      香港
# 2664  香港快運航空  ...       7.2    12.43      7.50     12      香港
# 2860                 70.8                                  71.627  0.631325
# 2883                 70.8                                  71.627  0.631325
# 2884                 70.8                                  71.627  0.631325
# 2885                 70.8                                  71.627  0.631325
# 2905                 70.8                                  71.627  0.631325
# 2926                 70.8                                  71.627  0.631325
# 2927                 70.8                                  71.627  0.631325
# 2928                 70.8                                  71.627  0.631325
# 2948                 70.8                                  71.627  0.631325
# 2969                 70.8                                  71.627  0.631325
# 2970                 70.8                                  71.627  0.631325
# 2971                 70.8                                  71.627  0.631325
# 2991                 70.8                                  71.627  0.631325
# 3034                 70.8                                  71.627  0.631325
# 3105                 70.8                                  71.627  0.631325
# 3106                 70.8                                  71.627  0.631325
# 3152                 70.8                                  71.627  0.631325
# 3153                 70.8                                  71.627  0.631325
# 3154                 70.8                                  71.627  0.631325
# 3178                 70.8                                  71.627  0.631325
# 3202                 70.8                                  71.627  0.631325
# 3203                 70.8                                  71.627  0.631325
# 3204                 70.8                                  71.627  0.631325
# 3224                 70.8                                  71.627  0.631325
# 3247                 70.8                                  71.627  0.631325
# 3248                 70.8                                  71.627  0.631325
# 3249                 70.8                                  71.627  0.631325
# 3269                 70.8                                  71.627  0.631325
#
#           機場指標 competing_flights
# 1723 -0.229905                21
# 1724 -0.229905                21
# 1790 -0.229905                24
# 1791 -0.229905                24
# 1792 -0.229905                24
# 1825 -0.229905                22
# 1857 -0.229905                23
# 1858 -0.229905                23
# 1859 -0.229905                23
# 1890 -0.229905                20
# 1921 -0.229905                23
# 1922 -0.229905                23
# 1923 -0.229905                23
# 1956 -0.229905                22
# 2600 -0.229905                14
# 2601 -0.229905                14
# 2621 -0.229905                13
# 2664 -0.229905                14
# 2771 -0.229905                15
# 2772 -0.229905                15
# 2825 -0.229905                24
# 2826 -0.229905                24
# 2827 -0.229905                24
# 2860 -0.229905                22
# 2883 -0.229905                16
# 2884 -0.229905                16
# 2885 -0.229905                16
# 2905 -0.229905                13
# 2926 -0.229905                14
# 2927 -0.229905                14
# 2928 -0.229905                14
# 2948 -0.229905                14
# 2969 -0.229905                15
# 2970 -0.229905                15
# 2971 -0.229905                15
# 2991 -0.229905                14
# 3034 -0.229905                12
# 3105 -0.229905                16
# 3106 -0.229905                16
# 3152 -0.229905                16
# 3153 -0.229905                16
# 3154 -0.229905                16
# 3178 -0.229905                15
# 3202 -0.229905                16
# 3203 -0.229905                16
# 3204 -0.229905                16
# 3224 -0.229905                13
# 3247 -0.229905                18
# 3248 -0.229905                18
# 3249 -0.229905                18
# 3269 -0.229905                14
#
# [51 rows x 42 columns]
# 最低價格的最小值的數量為： 51

# %% [markdown]
# **Histogram**

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# 繁體中文設定
plt.rcParams['font.sans-serif'] = ['Arial Unicode MS']
plt.rcParams['axes.unicode_minus'] = False

# 創建子圖
fig, axes = plt.subplots(3, 2, figsize=(20, 18))
bins = 30  # 設定直方圖的 bin 數量

# 第一個子圖：平均價格的直方圖
sns.histplot(plot_data['平均價格'], bins=bins, kde=False, color='#FF9999', ax=axes[0, 0])
axes[0, 0].set_title('平均價格的分佈')
axes[0, 0].set_xlabel('平均價格')
axes[0, 0].set_ylabel('頻率')

# 第二個子圖：最低價格的直方圖
sns.histplot(plot_data['最低價格'], bins=bins, kde=False, color='#99CCFF', ax=axes[0, 1])
axes[0, 1].set_title('最低價格的分佈')
axes[0, 1].set_xlabel('最低價格')
axes[0, 1].set_ylabel('頻率')

# 第三個子圖：最低價格剩餘天數的直方圖
sns.histplot(plot_data['最低價格剩餘天數'], bins=bins, kde=False, color='#FFCC99', ax=axes[1, 0])
axes[1, 0].set_title('最低價格剩餘天數的分佈')
axes[1, 0].set_xlabel('最低價格剩餘天數')
axes[1, 0].set_ylabel('頻率')

# 第四個子圖：價格變異的直方圖
sns.histplot(plot_data['價格變異'], bins=bins, kde=False, color='#CCCCFF', ax=axes[1, 1])
axes[1, 1].set_title('價格變異的分佈')
axes[1, 1].set_xlabel('價格變異')
axes[1, 1].set_ylabel('頻率')

# 第五個子圖：中位數的直方圖
sns.histplot(plot_data['中位數價格'], bins=bins, kde=False, color='#B3FFCC', ax=axes[2, 0])
axes[2, 0].set_title('中位數的分佈')
axes[2, 0].set_xlabel('中位數')
axes[2, 0].set_ylabel('頻率')

# 第六個子圖：隨機購買平均價格的直方圖
sns.histplot(plot_data['隨機購買平均價格'], bins=bins, kde=False, color='#FFCCCC', ax=axes[2, 1])
axes[2, 1].set_title('隨機購買平均價格的分佈')
axes[2, 1].set_xlabel('隨機購買平均價格')
axes[2, 1].set_ylabel('頻率')

# 調整佈局
plt.tight_layout()
plt.show()

# %% [markdown]
# **處理後：Histogram**

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# 繁體中文設定
plt.rcParams['font.sans-serif'] = ['Arial Unicode MS']
plt.rcParams['axes.unicode_minus'] = False

# 創建子圖，分別繪製平均價格（對數）、最低價格（對數）、最低價格剩餘天數（對數）、價格變異（對數）和中位數（對數）的直方圖
fig, axes = plt.subplots(3, 2, figsize=(20, 18))
bins = 30  # 設定直方圖的 bin 數量

# 第一個子圖：平均價格（對數）的直方圖
sns.histplot(plot_data['平均價格_log'], bins=bins, kde=False, color='#FF9999', ax=axes[0, 0])
axes[0, 0].set_title('平均價格（對數）的分佈')
axes[0, 0].set_xlabel('平均價格（對數）')
axes[0, 0].set_ylabel('頻率')

# 第二個子圖：最低價格（對數）的直方圖
sns.histplot(plot_data['最低價格_log'], bins=bins, kde=False, color='#99CCFF', ax=axes[0, 1])
axes[0, 1].set_title('最低價格（對數）的分佈')
axes[0, 1].set_xlabel('最低價格（對數）')
axes[0, 1].set_ylabel('頻率')

# 第三個子圖：最低價格天數的直方圖
sns.histplot(plot_data["最低價格剩餘天數"], bins=bins, kde=False, color='#FFCC99', ax=axes[1, 0])
axes[1, 0].set_title('最低價格天數的分佈')
axes[1, 0].set_xlabel('最低價格天數')
axes[1, 0].set_ylabel('頻率')

# 第四個子圖：價格變異（對數）的直方圖
sns.histplot(plot_data['價格變異_log'], bins=bins, kde=False, color='#CCCCFF', ax=axes[1, 1])
axes[1, 1].set_title('價格變異（對數）的分佈')
axes[1, 1].set_xlabel('價格變異（對數）')
axes[1, 1].set_ylabel('頻率')

# 第五個子圖：中位數（對數）的直方圖
sns.histplot(plot_data['中位數價格_log'], bins=bins, kde=False, color='#B3FFCC', ax=axes[2, 0])
axes[2, 0].set_title('中位數（對數）的分佈')
axes[2, 0].set_xlabel('中位數（對數）')
axes[2, 0].set_ylabel('頻率')

# 隱藏第六個子圖（無數據）
axes[2, 1].axis('off')

# 調整佈局
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# 繁體中文設定
plt.rcParams['font.sans-serif'] = ['Arial Unicode MS']
plt.rcParams['axes.unicode_minus'] = False

# 創建子圖
fig, axes = plt.subplots(3, 2, figsize=(20, 18))
bins = 30  # 設定直方圖的 bin 數量

# 第一個子圖：平均價格的直方圖
sns.histplot(plot_data['平均價格'], bins=bins, kde=False, color='#FF9999', ax=axes[0, 0])
axes[0, 0].set_title('平均價格的分佈')
axes[0, 0].set_xlabel('平均價格')
axes[0, 0].set_ylabel('頻率')

# 第二個子圖：平均價格（對數）的直方圖
sns.histplot(plot_data['平均價格_log'], bins=bins, kde=False, color='#FF9999', ax=axes[0, 1])
axes[0, 1].set_title('平均價格（對數）的分佈')
axes[0, 1].set_xlabel('平均價格（對數）')
axes[0, 1].set_ylabel('頻率')

# 第三個子圖：最低價格的直方圖
sns.histplot(plot_data['最低價格'], bins=bins, kde=False, color='#99CCFF', ax=axes[1, 0])
axes[1, 0].set_title('最低價格的分佈')
axes[1, 0].set_xlabel('最低價格')
axes[1, 0].set_ylabel('頻率')

# 第四個子圖：最低價格（對數）的直方圖
sns.histplot(plot_data['最低價格_log'], bins=bins, kde=False, color='#99CCFF', ax=axes[1, 1])
axes[1, 1].set_title('最低價格（對數）的分佈')
axes[1, 1].set_xlabel('最低價格（對數）')
axes[1, 1].set_ylabel('頻率')

# 第五個子圖：中位數的直方圖
sns.histplot(plot_data['中位數價格'], bins=bins, kde=False, color='#B3FFCC', ax=axes[2, 0])
axes[2, 0].set_title('中位數的分佈')
axes[2, 0].set_xlabel('中位數')
axes[2, 0].set_ylabel('頻率')

# 第六個子圖：中位數（對數）的直方圖
sns.histplot(plot_data['中位數價格_log'], bins=bins, kde=False, color='#B3FFCC', ax=axes[2, 1])
axes[2, 1].set_title('中位數（對數）的分佈')
axes[2, 1].set_xlabel('中位數（對數）')
axes[2, 1].set_ylabel('頻率')

# 調整佈局
plt.tight_layout()
plt.show()
