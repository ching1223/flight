# %% [markdown]
# # Histogram

# %%
import pandas as pd
from datetime import datetime
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# 載入資料並刪除價格歷史為空的列
data = pd.read_csv('/Users/yuchingchen/Documents/專題/cleaned_data/short_flight_final.csv')

# 移除包含 NaN 的數據
plot_data = data.dropna(subset=["平均價格_log", "最低價格_log", "最低價格天數", "價格變異_log", "中位數價格_log"])

min_value = plot_data['最低價格'].min()
print("最低價格的最小值為：", min_value)

# 用布林索引過濾出「最低價格」等於最小值的所有列
rows_with_min_value = plot_data[plot_data['最低價格'] == min_value]

print(rows_with_min_value)
print("最低價格的最小值的數量為：", len(rows_with_min_value))
# Out:
# 最低價格的最小值為： 1340
#             出發日期   星期    出發時間  出發時段 出發機場代號     抵達時間  抵達時段 抵達機場代號  機場分類  \
# 1606  2025-01-20  星期一  下午2:05  下午班機    TPE   下午4:05  下午抵達    HKG   2.0
# 1607  2025-01-20  星期一  下午2:50  下午班機    TPE   下午4:55  下午抵達    HKG   2.0
# 1673  2025-01-21  星期二  下午2:05  下午班機    TPE   下午4:05  下午抵達    HKG   2.0
# 1674  2025-01-21  星期二  下午2:50  下午班機    TPE   下午4:55  下午抵達    HKG   2.0
# 1675  2025-01-21  星期二  下午5:40  下午班機    TPE   晚上7:35  晚間抵達    HKG   2.0
# 1708  2025-01-21  星期二  晚上9:10  晚間班機    TPE  晚上11:10  晚間抵達    HKG   2.0
# 1739  2025-01-22  星期三  下午2:10  下午班機    TPE   下午4:05  下午抵達    HKG   2.0
# 1740  2025-01-22  星期三  下午2:50  下午班機    TPE   下午4:55  下午抵達    HKG   2.0
# 1741  2025-01-22  星期三  下午5:40  下午班機    TPE   晚上7:35  晚間抵達    HKG   2.0
# 1771  2025-01-22  星期三  晚上9:10  晚間班機    TPE  晚上11:10  晚間抵達    HKG   2.0
# 1795  2025-01-23  星期四  下午2:10  下午班機    TPE   下午4:05  下午抵達    HKG   2.0
# 1796  2025-01-23  星期四  下午2:50  下午班機    TPE   下午4:55  下午抵達    HKG   2.0
# 1797  2025-01-23  星期四  下午5:40  下午班機    TPE   晚上7:35  晚間抵達    HKG   2.0
# 1825  2025-01-23  星期四  晚上9:10  晚間班機    TPE  晚上11:10  晚間抵達    HKG   2.0
# 2415  2025-02-06  星期四  下午2:10  下午班機    TPE   下午4:05  下午抵達    HKG   2.0
# 2416  2025-02-06  星期四  下午2:50  下午班機    TPE   下午4:55  下午抵達    HKG   2.0
# 2436  2025-02-06  星期四  晚上9:10  晚間班機    TPE  晚上11:10  晚間抵達    HKG   2.0
# 2479  2025-02-07  星期五  晚上9:10  晚間班機    TPE  晚上11:10  晚間抵達    HKG   2.0
# 2585  2025-02-10  星期一  下午2:05  下午班機    TPE   下午4:05  下午抵達    HKG   2.0
# 2586  2025-02-10  星期一  下午2:50  下午班機    TPE   下午4:55  下午抵達    HKG   2.0
# 2639  2025-02-11  星期二  下午2:05  下午班機    TPE   下午4:05  下午抵達    HKG   2.0
# 2640  2025-02-11  星期二  下午2:50  下午班機    TPE   下午4:55  下午抵達    HKG   2.0
# 2641  2025-02-11  星期二  下午5:40  下午班機    TPE   晚上7:35  晚間抵達    HKG   2.0
# 2673  2025-02-11  星期二  晚上9:10  晚間班機    TPE  晚上11:10  晚間抵達    HKG   2.0
# 2696  2025-02-12  星期三  下午2:10  下午班機    TPE   下午4:05  下午抵達    HKG   2.0
# 2697  2025-02-12  星期三  下午2:50  下午班機    TPE   下午4:55  下午抵達    HKG   2.0
# 2698  2025-02-12  星期三  下午5:40  下午班機    TPE   晚上7:35  晚間抵達    HKG   2.0
# 2718  2025-02-12  星期三  晚上9:10  晚間班機    TPE  晚上11:10  晚間抵達    HKG   2.0
# 2739  2025-02-13  星期四  下午2:10  下午班機    TPE   下午4:05  下午抵達    HKG   2.0
# 2740  2025-02-13  星期四  下午2:50  下午班機    TPE   下午4:55  下午抵達    HKG   2.0
# 2741  2025-02-13  星期四  下午5:40  下午班機    TPE   晚上7:35  晚間抵達    HKG   2.0
# 2760  2025-02-13  星期四  晚上9:10  晚間班機    TPE  晚上11:10  晚間抵達    HKG   2.0
# 2781  2025-02-14  星期五  下午2:10  下午班機    TPE   下午4:05  下午抵達    HKG   2.0
# 2782  2025-02-14  星期五  下午2:50  下午班機    TPE   下午4:55  下午抵達    HKG   2.0
# 2783  2025-02-14  星期五  下午5:40  下午班機    TPE   晚上7:35  晚間抵達    HKG   2.0
# 2802  2025-02-14  星期五  晚上9:10  晚間班機    TPE  晚上11:10  晚間抵達    HKG   2.0
# 2845  2025-02-15  星期六  晚上9:10  晚間班機    TPE  晚上11:10  晚間抵達    HKG   2.0
# 2914  2025-02-17  星期一  下午2:05  下午班機    TPE   下午4:05  下午抵達    HKG   2.0
# 2915  2025-02-17  星期一  下午2:50  下午班機    TPE   下午4:55  下午抵達    HKG   2.0
# 2960  2025-02-18  星期二  下午2:05  下午班機    TPE   下午4:05  下午抵達    HKG   2.0
# 2961  2025-02-18  星期二  下午2:50  下午班機    TPE   下午4:55  下午抵達    HKG   2.0
# 2962  2025-02-18  星期二  下午5:40  下午班機    TPE   晚上7:35  晚間抵達    HKG   2.0
# 2985  2025-02-18  星期二  晚上9:10  晚間班機    TPE  晚上11:10  晚間抵達    HKG   2.0
# 3018  2025-02-19  星期三  下午2:10  下午班機    TPE   下午4:05  下午抵達    HKG   2.0
# 3019  2025-02-19  星期三  下午2:50  下午班機    TPE   下午4:55  下午抵達    HKG   2.0
# 3020  2025-02-19  星期三  下午5:40  下午班機    TPE   晚上7:35  晚間抵達    HKG   2.0
# 3050  2025-02-19  星期三  晚上9:10  晚間班機    TPE  晚上11:10  晚間抵達    HKG   2.0
# 3083  2025-02-20  星期四  下午2:10  下午班機    TPE   下午4:05  下午抵達    HKG   2.0
# 3084  2025-02-20  星期四  下午2:50  下午班機    TPE   下午4:55  下午抵達    HKG   2.0
# 3085  2025-02-20  星期四  下午5:40  下午班機    TPE   晚上7:35  晚間抵達    HKG   2.0
# 3118  2025-02-20  星期四  晚上9:10  晚間班機    TPE  晚上11:10  晚間抵達    HKG   2.0
#
#         航空公司  ...  最低價格_log 價格變異_log 中位數價格_log 最低價格天數  Region  \
# 1606  香港快運航空  ...       7.2    12.84      7.43     30      香港
# 1607  香港快運航空  ...       7.2    12.84      7.43     30      香港
# 1673  香港快運航空  ...       7.2    13.10      7.43     29      香港
# 1674  香港快運航空  ...       7.2    13.22      7.32     29      香港
# 1675  香港快運航空  ...       7.2    12.75      7.50     29      香港
# 1708  香港快運航空  ...       7.2    12.98      7.33     29      香港
# 1739  香港快運航空  ...       7.2    12.78      7.50     28      香港
# 1740  香港快運航空  ...       7.2    12.79      7.37     28      香港
# 1741  香港快運航空  ...       7.2    12.69      7.50     28      香港
# 1771  香港快運航空  ...       7.2    12.67      7.32     28      香港
# 1795  香港快運航空  ...       7.2    13.74      7.54     27      香港
# 1796  香港快運航空  ...       7.2    13.47      7.54     27      香港
# 1797  香港快運航空  ...       7.2    13.60      7.50     27      香港
# 1825  香港快運航空  ...       7.2    12.84      7.43     27      香港
# 2673                 70.8                                  71.627  0.631325
# 2696                 70.8                                  71.627  0.631325
# 2697                 70.8                                  71.627  0.631325
# 2698                 70.8                                  71.627  0.631325
# 2718                 70.8                                  71.627  0.631325
# 2739                 70.8                                  71.627  0.631325
# 2740                 70.8                                  71.627  0.631325
# 2741                 70.8                                  71.627  0.631325
# 2760                 70.8                                  71.627  0.631325
# 2781                 70.8                                  71.627  0.631325
# 2782                 70.8                                  71.627  0.631325
# 2783                 70.8                                  71.627  0.631325
# 2802                 70.8                                  71.627  0.631325
# 2845                 70.8                                  71.627  0.631325
# 2914                 70.8                                  71.627  0.631325
# 2915                 70.8                                  71.627  0.631325
# 2960                 70.8                                  71.627  0.631325
# 2961                 70.8                                  71.627  0.631325
# 2962                 70.8                                  71.627  0.631325
# 2985                 70.8                                  71.627  0.631325
# 3018                 70.8                                  71.627  0.631325
# 3019                 70.8                                  71.627  0.631325
# 3020                 70.8                                  71.627  0.631325
# 3050                 70.8                                  71.627  0.631325
# 3083                 70.8                                  71.627  0.631325
# 3084                 70.8                                  71.627  0.631325
# 3085                 70.8                                  71.627  0.631325
# 3118                 70.8                                  71.627  0.631325
#
#           機場指標 competing_flights
# 1606 -0.229905                21
# 1607 -0.229905                21
# 1673 -0.229905                24
# 1674 -0.229905                24
# 1675 -0.229905                24
# 1708 -0.229905                22
# 1739 -0.229905                22
# 1740 -0.229905                22
# 1741 -0.229905                22
# 1771 -0.229905                19
# 1795 -0.229905                18
# 1796 -0.229905                18
# 1797 -0.229905                18
# 1825 -0.229905                19
# 2415 -0.229905                14
# 2416 -0.229905                14
# 2436 -0.229905                13
# 2479 -0.229905                14
# 2585 -0.229905                15
# 2586 -0.229905                15
# 2639 -0.229905                24
# 2640 -0.229905                24
# 2641 -0.229905                24
# 2673 -0.229905                22
# 2696 -0.229905                16
# 2697 -0.229905                16
# 2698 -0.229905                16
# 2718 -0.229905                13
# 2739 -0.229905                14
# 2740 -0.229905                14
# 2741 -0.229905                14
# 2760 -0.229905                14
# 2781 -0.229905                15
# 2782 -0.229905                15
# 2783 -0.229905                15
# 2802 -0.229905                14
# 2845 -0.229905                12
# 2914 -0.229905                16
# 2915 -0.229905                16
# 2960 -0.229905                16
# 2961 -0.229905                16
# 2962 -0.229905                16
# 2985 -0.229905                15
# 3018 -0.229905                24
# 3019 -0.229905                24
# 3020 -0.229905                24
# 3050 -0.229905                20
# 3083 -0.229905                24
# 3084 -0.229905                24
# 3085 -0.229905                24
# 3118 -0.229905                22
#
# [51 rows x 41 columns]
# 最低價格的最小值的數量為： 51

# %% [markdown]
# **Histogram**

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# 繁體中文設定
plt.rcParams['font.sans-serif'] = ['Arial Unicode MS']
plt.rcParams['axes.unicode_minus'] = False

# 創建子圖
fig, axes = plt.subplots(3, 2, figsize=(20, 18))
bins = 30  # 設定直方圖的 bin 數量

# 第一個子圖：平均價格的直方圖
sns.histplot(plot_data['平均價格'], bins=bins, kde=False, color='#FF9999', ax=axes[0, 0])
axes[0, 0].set_title('平均價格的分佈')
axes[0, 0].set_xlabel('平均價格')
axes[0, 0].set_ylabel('頻率')

# 第二個子圖：最低價格的直方圖
sns.histplot(plot_data['最低價格'], bins=bins, kde=False, color='#99CCFF', ax=axes[0, 1])
axes[0, 1].set_title('最低價格的分佈')
axes[0, 1].set_xlabel('最低價格')
axes[0, 1].set_ylabel('頻率')

# 第三個子圖：最低價格剩餘天數的直方圖
sns.histplot(plot_data['最低價格剩餘天數'], bins=bins, kde=False, color='#FFCC99', ax=axes[1, 0])
axes[1, 0].set_title('最低價格剩餘天數的分佈')
axes[1, 0].set_xlabel('最低價格剩餘天數')
axes[1, 0].set_ylabel('頻率')

# 第四個子圖：價格變異的直方圖
sns.histplot(plot_data['價格變異'], bins=bins, kde=False, color='#CCCCFF', ax=axes[1, 1])
axes[1, 1].set_title('價格變異的分佈')
axes[1, 1].set_xlabel('價格變異')
axes[1, 1].set_ylabel('頻率')

# 第五個子圖：中位數的直方圖
sns.histplot(plot_data['中位數價格'], bins=bins, kde=False, color='#B3FFCC', ax=axes[2, 0])
axes[2, 0].set_title('中位數的分佈')
axes[2, 0].set_xlabel('中位數')
axes[2, 0].set_ylabel('頻率')

# 隱藏第六個子圖（無數據）
axes[2, 1].axis('off')

# 調整佈局
plt.tight_layout()
plt.show()

# %% [markdown]
# **處理後：Histogram**

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# 繁體中文設定
plt.rcParams['font.sans-serif'] = ['Arial Unicode MS']
plt.rcParams['axes.unicode_minus'] = False

# 創建子圖，分別繪製平均價格（對數）、最低價格（對數）、最低價格剩餘天數（對數）、價格變異（對數）和中位數（對數）的直方圖
fig, axes = plt.subplots(3, 2, figsize=(20, 18))
bins = 30  # 設定直方圖的 bin 數量

# 第一個子圖：平均價格（對數）的直方圖
sns.histplot(plot_data['平均價格_log'], bins=bins, kde=False, color='#FF9999', ax=axes[0, 0])
axes[0, 0].set_title('平均價格（對數）的分佈')
axes[0, 0].set_xlabel('平均價格（對數）')
axes[0, 0].set_ylabel('頻率')

# 第二個子圖：最低價格（對數）的直方圖
sns.histplot(plot_data['最低價格_log'], bins=bins, kde=False, color='#99CCFF', ax=axes[0, 1])
axes[0, 1].set_title('最低價格（對數）的分佈')
axes[0, 1].set_xlabel('最低價格（對數）')
axes[0, 1].set_ylabel('頻率')

# 第三個子圖：最低價格天數的直方圖
sns.histplot(plot_data["最低價格剩餘天數"], bins=bins, kde=False, color='#FFCC99', ax=axes[1, 0])
axes[1, 0].set_title('最低價格天數的分佈')
axes[1, 0].set_xlabel('最低價格天數')
axes[1, 0].set_ylabel('頻率')

# 第四個子圖：價格變異（對數）的直方圖
sns.histplot(plot_data['價格變異_log'], bins=bins, kde=False, color='#CCCCFF', ax=axes[1, 1])
axes[1, 1].set_title('價格變異（對數）的分佈')
axes[1, 1].set_xlabel('價格變異（對數）')
axes[1, 1].set_ylabel('頻率')

# 第五個子圖：中位數（對數）的直方圖
sns.histplot(plot_data['中位數價格_log'], bins=bins, kde=False, color='#B3FFCC', ax=axes[2, 0])
axes[2, 0].set_title('中位數（對數）的分佈')
axes[2, 0].set_xlabel('中位數（對數）')
axes[2, 0].set_ylabel('頻率')

# 隱藏第六個子圖（無數據）
axes[2, 1].axis('off')

# 調整佈局
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# 繁體中文設定
plt.rcParams['font.sans-serif'] = ['Arial Unicode MS']
plt.rcParams['axes.unicode_minus'] = False

# 創建子圖
fig, axes = plt.subplots(3, 2, figsize=(20, 18))
bins = 30  # 設定直方圖的 bin 數量

# 第一個子圖：平均價格的直方圖
sns.histplot(plot_data['平均價格'], bins=bins, kde=False, color='#FF9999', ax=axes[0, 0])
axes[0, 0].set_title('平均價格的分佈')
axes[0, 0].set_xlabel('平均價格')
axes[0, 0].set_ylabel('頻率')

# 第二個子圖：平均價格（對數）的直方圖
sns.histplot(plot_data['平均價格_log'], bins=bins, kde=False, color='#FF9999', ax=axes[0, 1])
axes[0, 1].set_title('平均價格（對數）的分佈')
axes[0, 1].set_xlabel('平均價格（對數）')
axes[0, 1].set_ylabel('頻率')

# 第三個子圖：最低價格的直方圖
sns.histplot(plot_data['最低價格'], bins=bins, kde=False, color='#99CCFF', ax=axes[1, 0])
axes[1, 0].set_title('最低價格的分佈')
axes[1, 0].set_xlabel('最低價格')
axes[1, 0].set_ylabel('頻率')

# 第四個子圖：最低價格（對數）的直方圖
sns.histplot(plot_data['最低價格_log'], bins=bins, kde=False, color='#99CCFF', ax=axes[1, 1])
axes[1, 1].set_title('最低價格（對數）的分佈')
axes[1, 1].set_xlabel('最低價格（對數）')
axes[1, 1].set_ylabel('頻率')

# 第五個子圖：中位數的直方圖
sns.histplot(plot_data['中位數價格'], bins=bins, kde=False, color='#B3FFCC', ax=axes[2, 0])
axes[2, 0].set_title('中位數的分佈')
axes[2, 0].set_xlabel('中位數')
axes[2, 0].set_ylabel('頻率')

# 第六個子圖：中位數（對數）的直方圖
sns.histplot(plot_data['中位數價格_log'], bins=bins, kde=False, color='#B3FFCC', ax=axes[2, 1])
axes[2, 1].set_title('中位數（對數）的分佈')
axes[2, 1].set_xlabel('中位數（對數）')
axes[2, 1].set_ylabel('頻率')

# 調整佈局
plt.tight_layout()
plt.show()
